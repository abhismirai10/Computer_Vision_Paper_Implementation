# %%
import torch
import torch.nn as nn
import torch.optim as optim 
from torch.utils.data import DataLoader, random_split
import torchvision.transforms as transforms
import torchvision.datasets as datasets

import time
import numpy as np
import matplotlib.pyplot as plt

# Set device
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cpu')

# %%
#dataset preparation

# Hyperparameters
input_size = 784 # 28x28
num_classes = 10
batch_size = 64

# Load Data
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.1307,), (0.3081,))   #to first arg is mean value and second arg is standard deviation
])

# Download and prepare the MNIST dataset
train_dataset = datasets.MNIST(root='mnist_dataset/', train=True, transform=transform, download=True)
test_dataset = datasets.MNIST(root='mnist_dataset/', train=False, transform=transform, download=True)

# Split training dataset into training and validation
train_size = int(0.8 * len(train_dataset))
val_size = len(train_dataset) - train_size
train_dataset, val_dataset = random_split(train_dataset, [train_size, val_size])

train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(dataset=val_dataset, batch_size=batch_size, shuffle=False)
test_loader = DataLoader(dataset=test_dataset, batch_size=batch_size, shuffle=False)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to mnist_dataset/MNIST/raw/train-images-idx3-ubyte.gz
# 100.0%
# Extracting mnist_dataset/MNIST/raw/train-images-idx3-ubyte.gz to mnist_dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to mnist_dataset/MNIST/raw/train-labels-idx1-ubyte.gz
# 100.0%
# Extracting mnist_dataset/MNIST/raw/train-labels-idx1-ubyte.gz to mnist_dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to mnist_dataset/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100.0%
# Extracting mnist_dataset/MNIST/raw/t10k-images-idx3-ubyte.gz to mnist_dataset/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# 100.0%
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to mnist_dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz
# Extracting mnist_dataset/MNIST/raw/t10k-labels-idx1-ubyte.gz to mnist_dataset/MNIST/raw

# %%
# Function to visualize 5 random images with their labels
def visualize_random_images(dataset):
    fig, axes = plt.subplots(1, 5, figsize=(15, 3))
    for ax in axes:
        index = np.random.randint(0, len(dataset))
        img, label = dataset[index]
        img = img.numpy().squeeze()
        ax.imshow(img, cmap='gray')
        ax.set_title(f'Label: {label}')
        ax.axis('off')
    plt.show()

# Visualize training and validation images
print("Training Images:")
visualize_random_images(train_dataset)
print("Validation Images:")
visualize_random_images(val_dataset)
# Out:
# Training Images:
# Validation Images:

# %%
# Function for training the model
def train(model, loader, criterion, optimizer):
    model.train()
    running_loss = 0
    correct = 0
    total = 0
    for data, targets in loader:
        data = data.to(device)
        targets = targets.to(device)
        
        # Forward pass
        scores = model(data)
        loss = criterion(scores, targets)
        
        # Backward pass
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        # Statistics
        running_loss += loss.item()
        _, predictions = scores.max(1)
        correct += (predictions == targets).sum().item()
        total += targets.size(0)
    
    epoch_loss = running_loss / len(loader)
    epoch_acc = correct / total
    return epoch_loss, epoch_acc

# Function for evaluating the model
def evaluate(model, loader, criterion):
    model.eval()
    running_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for data, targets in loader:
            data = data.to(device)
            targets = targets.to(device)
            
            # Forward pass
            scores = model(data)
            loss = criterion(scores, targets)
            
            # Statistics
            running_loss += loss.item()
            _, predictions = scores.max(1)
            correct += (predictions == targets).sum().item()
            total += targets.size(0)
    
    epoch_loss = running_loss / len(loader)
    epoch_acc = correct / total
    return epoch_loss, epoch_acc

# %%
# Define the Neural Network
class fc(nn.Module):
    def __init__(self, input_size, num_classes):
        super(fc, self).__init__()
        self.fc1 = nn.Linear(input_size, 128)
        self.fc2 = nn.Linear(128, 64)
        self.fc3 = nn.Linear(64, num_classes)
    
    def forward(self, x):
        x = x.reshape(x.shape[0], -1)
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Initialize network
model = fc(input_size=input_size, num_classes=num_classes).to(device)

# %%
#hyperparameter
learning_rate = 0.001

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# Training loop
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

num_epochs = 100

# %%
# Record the start time
start_time = time.time()

#start training
for epoch in range(num_epochs):
    train_loss, train_acc = train(model, train_loader, criterion, optimizer)
    val_loss, val_acc = evaluate(model, val_loader, criterion)
    
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    
    print(f'Epoch [{epoch+1}/{num_epochs}]: Train Loss: {train_loss:.4f}, Train Acc: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Acc: {val_acc:.4f}')

# Record the end time
end_time = time.time()
total_time = end_time - start_time

print(f'Total training time: {total_time:.2f} seconds')

# Plotting the training and validation loss and accuracy
epochs = range(1, num_epochs + 1)

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(epochs, train_losses, label='Train Loss')
plt.plot(epochs, val_losses, label='Val Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.title('Loss over Epochs')

plt.subplot(1, 2, 2)
plt.plot(epochs, train_accuracies, label='Train Accuracy')
plt.plot(epochs, val_accuracies, label='Val Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.title('Accuracy over Epochs')

plt.show()
# Out:
# Epoch [1/100]: Train Loss: 0.3047, Train Acc: 0.9115, Val Loss: 0.1572, Val Acc: 0.9525
# Epoch [2/100]: Train Loss: 0.1219, Train Acc: 0.9629, Val Loss: 0.1207, Val Acc: 0.9615
# Epoch [3/100]: Train Loss: 0.0850, Train Acc: 0.9735, Val Loss: 0.1039, Val Acc: 0.9670
# Epoch [4/100]: Train Loss: 0.0641, Train Acc: 0.9796, Val Loss: 0.0984, Val Acc: 0.9695
# Epoch [5/100]: Train Loss: 0.0536, Train Acc: 0.9821, Val Loss: 0.1005, Val Acc: 0.9704
# Epoch [6/100]: Train Loss: 0.0409, Train Acc: 0.9863, Val Loss: 0.1017, Val Acc: 0.9718
# Epoch [7/100]: Train Loss: 0.0357, Train Acc: 0.9884, Val Loss: 0.1244, Val Acc: 0.9663
# Epoch [8/100]: Train Loss: 0.0287, Train Acc: 0.9902, Val Loss: 0.0995, Val Acc: 0.9742
# Epoch [9/100]: Train Loss: 0.0253, Train Acc: 0.9914, Val Loss: 0.1298, Val Acc: 0.9676
# Epoch [10/100]: Train Loss: 0.0248, Train Acc: 0.9916, Val Loss: 0.0979, Val Acc: 0.9764
# Epoch [11/100]: Train Loss: 0.0207, Train Acc: 0.9924, Val Loss: 0.1074, Val Acc: 0.9738
# Epoch [12/100]: Train Loss: 0.0184, Train Acc: 0.9939, Val Loss: 0.1048, Val Acc: 0.9751
# Epoch [13/100]: Train Loss: 0.0177, Train Acc: 0.9941, Val Loss: 0.1133, Val Acc: 0.9752
# Epoch [14/100]: Train Loss: 0.0171, Train Acc: 0.9940, Val Loss: 0.1152, Val Acc: 0.9753
# Epoch [15/100]: Train Loss: 0.0158, Train Acc: 0.9943, Val Loss: 0.1375, Val Acc: 0.9721
# Epoch [16/100]: Train Loss: 0.0161, Train Acc: 0.9946, Val Loss: 0.1281, Val Acc: 0.9764
# Epoch [17/100]: Train Loss: 0.0129, Train Acc: 0.9955, Val Loss: 0.1172, Val Acc: 0.9772
# Epoch [18/100]: Train Loss: 0.0145, Train Acc: 0.9952, Val Loss: 0.1510, Val Acc: 0.9718
# Epoch [19/100]: Train Loss: 0.0155, Train Acc: 0.9948, Val Loss: 0.1461, Val Acc: 0.9736
# Epoch [20/100]: Train Loss: 0.0130, Train Acc: 0.9956, Val Loss: 0.1360, Val Acc: 0.9756
# Epoch [21/100]: Train Loss: 0.0101, Train Acc: 0.9966, Val Loss: 0.1512, Val Acc: 0.9742
# Epoch [22/100]: Train Loss: 0.0129, Train Acc: 0.9960, Val Loss: 0.1433, Val Acc: 0.9765
# Epoch [23/100]: Train Loss: 0.0101, Train Acc: 0.9965, Val Loss: 0.1588, Val Acc: 0.9738
# Epoch [24/100]: Train Loss: 0.0067, Train Acc: 0.9978, Val Loss: 0.1454, Val Acc: 0.9759
# Epoch [25/100]: Train Loss: 0.0153, Train Acc: 0.9949, Val Loss: 0.1476, Val Acc: 0.9752
# Epoch [26/100]: Train Loss: 0.0079, Train Acc: 0.9973, Val Loss: 0.1366, Val Acc: 0.9777
# Epoch [27/100]: Train Loss: 0.0120, Train Acc: 0.9960, Val Loss: 0.1615, Val Acc: 0.9744
# Epoch [28/100]: Train Loss: 0.0091, Train Acc: 0.9971, Val Loss: 0.1726, Val Acc: 0.9751
# Epoch [29/100]: Train Loss: 0.0120, Train Acc: 0.9964, Val Loss: 0.1609, Val Acc: 0.9754
# Epoch [30/100]: Train Loss: 0.0055, Train Acc: 0.9982, Val Loss: 0.1964, Val Acc: 0.9732
# Epoch [31/100]: Train Loss: 0.0096, Train Acc: 0.9969, Val Loss: 0.1430, Val Acc: 0.9781
# Epoch [32/100]: Train Loss: 0.0116, Train Acc: 0.9966, Val Loss: 0.1810, Val Acc: 0.9721
# Epoch [33/100]: Train Loss: 0.0089, Train Acc: 0.9971, Val Loss: 0.1732, Val Acc: 0.9763
# Epoch [34/100]: Train Loss: 0.0089, Train Acc: 0.9971, Val Loss: 0.1811, Val Acc: 0.9755
# Epoch [35/100]: Train Loss: 0.0086, Train Acc: 0.9974, Val Loss: 0.1826, Val Acc: 0.9736
# Epoch [36/100]: Train Loss: 0.0066, Train Acc: 0.9977, Val Loss: 0.1739, Val Acc: 0.9738
# Epoch [37/100]: Train Loss: 0.0122, Train Acc: 0.9963, Val Loss: 0.1905, Val Acc: 0.9757
# Epoch [38/100]: Train Loss: 0.0077, Train Acc: 0.9978, Val Loss: 0.1790, Val Acc: 0.9780
# Epoch [39/100]: Train Loss: 0.0064, Train Acc: 0.9980, Val Loss: 0.1824, Val Acc: 0.9758
# Epoch [40/100]: Train Loss: 0.0136, Train Acc: 0.9964, Val Loss: 0.1886, Val Acc: 0.9756
# Epoch [41/100]: Train Loss: 0.0036, Train Acc: 0.9987, Val Loss: 0.2135, Val Acc: 0.9742
# Epoch [42/100]: Train Loss: 0.0093, Train Acc: 0.9970, Val Loss: 0.2041, Val Acc: 0.9742
# Epoch [43/100]: Train Loss: 0.0103, Train Acc: 0.9970, Val Loss: 0.1874, Val Acc: 0.9788
# Epoch [44/100]: Train Loss: 0.0044, Train Acc: 0.9986, Val Loss: 0.1947, Val Acc: 0.9761
# Epoch [45/100]: Train Loss: 0.0063, Train Acc: 0.9980, Val Loss: 0.2210, Val Acc: 0.9752
# Epoch [46/100]: Train Loss: 0.0112, Train Acc: 0.9968, Val Loss: 0.2188, Val Acc: 0.9749
# Epoch [47/100]: Train Loss: 0.0054, Train Acc: 0.9985, Val Loss: 0.2542, Val Acc: 0.9704
# Epoch [48/100]: Train Loss: 0.0061, Train Acc: 0.9980, Val Loss: 0.2337, Val Acc: 0.9746
# Epoch [49/100]: Train Loss: 0.0075, Train Acc: 0.9977, Val Loss: 0.2581, Val Acc: 0.9737
# Epoch [50/100]: Train Loss: 0.0100, Train Acc: 0.9972, Val Loss: 0.2229, Val Acc: 0.9778
# Epoch [51/100]: Train Loss: 0.0083, Train Acc: 0.9979, Val Loss: 0.1977, Val Acc: 0.9783
# Epoch [52/100]: Train Loss: 0.0016, Train Acc: 0.9996, Val Loss: 0.1946, Val Acc: 0.9792
# Epoch [53/100]: Train Loss: 0.0095, Train Acc: 0.9975, Val Loss: 0.2189, Val Acc: 0.9768
# Epoch [54/100]: Train Loss: 0.0109, Train Acc: 0.9971, Val Loss: 0.2372, Val Acc: 0.9768
# Epoch [55/100]: Train Loss: 0.0060, Train Acc: 0.9984, Val Loss: 0.2280, Val Acc: 0.9756
# Epoch [56/100]: Train Loss: 0.0074, Train Acc: 0.9981, Val Loss: 0.2572, Val Acc: 0.9744
# Epoch [57/100]: Train Loss: 0.0061, Train Acc: 0.9981, Val Loss: 0.2493, Val Acc: 0.9750
# Epoch [58/100]: Train Loss: 0.0102, Train Acc: 0.9973, Val Loss: 0.2892, Val Acc: 0.9735
# Epoch [59/100]: Train Loss: 0.0069, Train Acc: 0.9983, Val Loss: 0.2429, Val Acc: 0.9782
# Epoch [60/100]: Train Loss: 0.0078, Train Acc: 0.9981, Val Loss: 0.2402, Val Acc: 0.9773
# Epoch [61/100]: Train Loss: 0.0044, Train Acc: 0.9986, Val Loss: 0.2543, Val Acc: 0.9747
# Epoch [62/100]: Train Loss: 0.0063, Train Acc: 0.9985, Val Loss: 0.2360, Val Acc: 0.9785
# Epoch [63/100]: Train Loss: 0.0099, Train Acc: 0.9977, Val Loss: 0.2249, Val Acc: 0.9784
# Epoch [64/100]: Train Loss: 0.0043, Train Acc: 0.9986, Val Loss: 0.2226, Val Acc: 0.9788
# Epoch [65/100]: Train Loss: 0.0063, Train Acc: 0.9982, Val Loss: 0.2690, Val Acc: 0.9758
# Epoch [66/100]: Train Loss: 0.0085, Train Acc: 0.9978, Val Loss: 0.2448, Val Acc: 0.9767
# Epoch [67/100]: Train Loss: 0.0060, Train Acc: 0.9984, Val Loss: 0.2423, Val Acc: 0.9780
# Epoch [68/100]: Train Loss: 0.0054, Train Acc: 0.9984, Val Loss: 0.2649, Val Acc: 0.9772
# Epoch [69/100]: Train Loss: 0.0079, Train Acc: 0.9981, Val Loss: 0.2568, Val Acc: 0.9772
# Epoch [70/100]: Train Loss: 0.0059, Train Acc: 0.9985, Val Loss: 0.2723, Val Acc: 0.9762
# Epoch [71/100]: Train Loss: 0.0064, Train Acc: 0.9983, Val Loss: 0.2467, Val Acc: 0.9770
# Epoch [72/100]: Train Loss: 0.0061, Train Acc: 0.9985, Val Loss: 0.2720, Val Acc: 0.9758
# Epoch [73/100]: Train Loss: 0.0068, Train Acc: 0.9982, Val Loss: 0.2653, Val Acc: 0.9776
# Epoch [74/100]: Train Loss: 0.0057, Train Acc: 0.9986, Val Loss: 0.2682, Val Acc: 0.9768
# Epoch [75/100]: Train Loss: 0.0057, Train Acc: 0.9986, Val Loss: 0.2720, Val Acc: 0.9770
# Epoch [76/100]: Train Loss: 0.0109, Train Acc: 0.9978, Val Loss: 0.2606, Val Acc: 0.9774
# Epoch [77/100]: Train Loss: 0.0053, Train Acc: 0.9987, Val Loss: 0.2598, Val Acc: 0.9780
# Epoch [78/100]: Train Loss: 0.0033, Train Acc: 0.9992, Val Loss: 0.2737, Val Acc: 0.9775
# Epoch [79/100]: Train Loss: 0.0118, Train Acc: 0.9971, Val Loss: 0.2833, Val Acc: 0.9745
# Epoch [80/100]: Train Loss: 0.0051, Train Acc: 0.9985, Val Loss: 0.2538, Val Acc: 0.9792
# Epoch [81/100]: Train Loss: 0.0010, Train Acc: 0.9997, Val Loss: 0.2425, Val Acc: 0.9799
# Epoch [82/100]: Train Loss: 0.0047, Train Acc: 0.9988, Val Loss: 0.2800, Val Acc: 0.9761
# Epoch [83/100]: Train Loss: 0.0160, Train Acc: 0.9963, Val Loss: 0.2947, Val Acc: 0.9762
# Epoch [84/100]: Train Loss: 0.0055, Train Acc: 0.9988, Val Loss: 0.2817, Val Acc: 0.9775
# Epoch [85/100]: Train Loss: 0.0035, Train Acc: 0.9990, Val Loss: 0.3017, Val Acc: 0.9769
# Epoch [86/100]: Train Loss: 0.0064, Train Acc: 0.9982, Val Loss: 0.3155, Val Acc: 0.9759
# Epoch [87/100]: Train Loss: 0.0089, Train Acc: 0.9981, Val Loss: 0.2844, Val Acc: 0.9772
# Epoch [88/100]: Train Loss: 0.0031, Train Acc: 0.9992, Val Loss: 0.2721, Val Acc: 0.9770
# Epoch [89/100]: Train Loss: 0.0082, Train Acc: 0.9979, Val Loss: 0.3299, Val Acc: 0.9734
# Epoch [90/100]: Train Loss: 0.0037, Train Acc: 0.9990, Val Loss: 0.2856, Val Acc: 0.9773
# Epoch [91/100]: Train Loss: 0.0075, Train Acc: 0.9982, Val Loss: 0.3057, Val Acc: 0.9755
# Epoch [92/100]: Train Loss: 0.0027, Train Acc: 0.9993, Val Loss: 0.2954, Val Acc: 0.9777
# Epoch [93/100]: Train Loss: 0.0094, Train Acc: 0.9980, Val Loss: 0.3186, Val Acc: 0.9765
# Epoch [94/100]: Train Loss: 0.0073, Train Acc: 0.9984, Val Loss: 0.3521, Val Acc: 0.9753
# Epoch [95/100]: Train Loss: 0.0038, Train Acc: 0.9989, Val Loss: 0.3393, Val Acc: 0.9744
# Epoch [96/100]: Train Loss: 0.0033, Train Acc: 0.9993, Val Loss: 0.3543, Val Acc: 0.9759
# Epoch [97/100]: Train Loss: 0.0088, Train Acc: 0.9983, Val Loss: 0.3117, Val Acc: 0.9759
# Epoch [98/100]: Train Loss: 0.0076, Train Acc: 0.9983, Val Loss: 0.3216, Val Acc: 0.9763
# Epoch [99/100]: Train Loss: 0.0085, Train Acc: 0.9981, Val Loss: 0.3181, Val Acc: 0.9771
# Epoch [100/100]: Train Loss: 0.0039, Train Acc: 0.9992, Val Loss: 0.3139, Val Acc: 0.9762
# Total training time: 305.64 seconds

# %%
# Evaluate the model on test data and collect predictions
def evaluate_and_collect_predictions(model, loader, criterion):
    model.eval()
    running_loss = 0
    correct = 0
    total = 0
    correct_images = []
    incorrect_images = []
    correct_labels = []
    incorrect_labels = []
    predicted_labels_correct = []
    predicted_labels_incorrect = []

    with torch.no_grad():
        for data, targets in loader:
            data = data.to(device)
            targets = targets.to(device)
            
            # Forward pass
            outputs = model(data)
            loss = criterion(outputs, targets)
            
            # Statistics
            running_loss += loss.item()
            _, predicted = outputs.max(1)
            correct += (predicted == targets).sum().item()
            total += targets.size(0)

            for i in range(data.size(0)):
                if predicted[i] == targets[i]:
                    correct_images.append(data[i].cpu())
                    correct_labels.append(targets[i].cpu())
                    predicted_labels_correct.append(predicted[i].cpu())
                else:
                    incorrect_images.append(data[i].cpu())
                    incorrect_labels.append(targets[i].cpu())
                    predicted_labels_incorrect.append(predicted[i].cpu())

    epoch_loss = running_loss / len(loader)
    epoch_acc = correct / total

    return epoch_loss, epoch_acc, correct_images, incorrect_images, correct_labels, incorrect_labels, predicted_labels_correct, predicted_labels_incorrect

# Call the modified evaluation function
test_loss, test_acc, correct_images, incorrect_images, correct_labels, incorrect_labels, predicted_labels_correct, predicted_labels_incorrect = evaluate_and_collect_predictions(model, test_loader, criterion)
print(f'Test Loss: {test_loss:.4f}, Test Accuracy: {test_acc:.4f}')

# Function to visualize 5 random correct and incorrect predictions
def visualize_random_predictions(correct_images, incorrect_images, correct_labels, incorrect_labels, predicted_labels_correct, predicted_labels_incorrect):
    fig, axes = plt.subplots(1, 5, figsize=(15, 3))
    for ax in axes:
        idx = np.random.randint(0, len(correct_images))
        img = correct_images[idx].numpy().squeeze()
        true_label = correct_labels[idx].item()
        pred_label = predicted_labels_correct[idx].item()
        ax.imshow(img, cmap='gray')
        ax.set_title(f'True: {true_label}, Pred: {pred_label}')
        ax.axis('off')
    plt.suptitle('Correct Predictions')
    plt.show()

    fig, axes = plt.subplots(1, 5, figsize=(15, 3))
    for ax in axes:
        idx = np.random.randint(0, len(incorrect_images))
        img = incorrect_images[idx].numpy().squeeze()
        true_label = incorrect_labels[idx].item()
        pred_label = predicted_labels_incorrect[idx].item()
        ax.imshow(img, cmap='gray')
        ax.set_title(f'True: {true_label}, Pred: {pred_label}')
        ax.axis('off')
    plt.suptitle('Incorrect Predictions')
    plt.show()

# Visualize the predictions
visualize_random_predictions(correct_images, incorrect_images, correct_labels, incorrect_labels, predicted_labels_correct, predicted_labels_incorrect)
# Out:
# Test Loss: 0.2464, Test Accuracy: 0.9775
